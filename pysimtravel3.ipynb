# %%
# %pip install matplotlib
# %pip install ipympl
# %matplotlib ipympl
# Out:
# Requirement already satisfied: matplotlib in c:\software\python\python311\lib\site-packages (3.7.2)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: contourpy>=1.0.1 in c:\software\python\python311\lib\site-packages (from matplotlib) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\software\python\python311\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\software\python\python311\lib\site-packages (from matplotlib) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\software\python\python311\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in c:\software\python\python311\lib\site-packages (from matplotlib) (1.25.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\software\python\python311\lib\site-packages (from matplotlib) (10.0.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\software\python\python311\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: ipympl in c:\software\python\python311\lib\site-packages (0.9.3)
# Requirement already satisfied: ipython<9 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from ipympl) (8.15.0)
# Requirement already satisfied: numpy in c:\software\python\python311\lib\site-packages (from ipympl) (1.25.2)
# Requirement already satisfied: ipython-genutils in c:\software\python\python311\lib\site-packages (from ipympl) (0.2.0)
# Requirement already satisfied: pillow in c:\software\python\python311\lib\site-packages (from ipympl) (10.0.0)
# Requirement already satisfied: traitlets<6 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from ipympl) (5.9.0)
# Requirement already satisfied: ipywidgets<9,>=7.6.0 in c:\software\python\python311\lib\site-packages (from ipympl) (8.1.0)
# Requirement already satisfied: matplotlib<4,>=3.4.0 in c:\software\python\python311\lib\site-packages (from ipympl) (3.7.2)
# Requirement already satisfied: backcall in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (0.2.0)
# Requirement already satisfied: decorator in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (0.19.0)
# Requirement already satisfied: matplotlib-inline in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (0.1.6)
# Requirement already satisfied: pickleshare in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (3.0.39)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (2.16.1)
# Requirement already satisfied: stack-data in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (0.6.2)
# Requirement already satisfied: colorama in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from ipython<9->ipympl) (0.4.6)
# Requirement already satisfied: comm>=0.1.3 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.1.4)
# Requirement already satisfied: widgetsnbextension~=4.0.7 in c:\software\python\python311\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (4.0.8)
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in c:\software\python\python311\lib\site-packages (from ipywidgets<9,>=7.6.0->ipympl) (3.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in c:\software\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in c:\software\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\software\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (4.42.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\software\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from matplotlib<4,>=3.4.0->ipympl) (23.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\software\python\python311\lib\site-packages (from matplotlib<4,>=3.4.0->ipympl) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from matplotlib<4,>=3.4.0->ipympl) (2.8.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from jedi>=0.16->ipython<9->ipympl) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython<9->ipympl) (0.2.6)
# Requirement already satisfied: six>=1.5 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.4.0->ipympl) (1.16.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from stack-data->ipython<9->ipympl) (1.2.0)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from stack-data->ipython<9->ipympl) (2.4.0)
# Requirement already satisfied: pure-eval in c:\users\maría josé morón\appdata\roaming\python\python311\site-packages (from stack-data->ipython<9->ipympl) (0.2.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import cellclass
from cellclass import Cell
import citybuilder
from citybuilder import Parameters, Block, City

# %%
# Initialization
N = 100
initial_states = np.random.choice([Cell.ON, Cell.OFF], N*N, p=[0.2, 0.8])
grid = np.array([Cell(state) for state in initial_states]).reshape(N, N)

# Set neighbors
for i in range(N):
    for j in range(N):
        for di in [-1, 0, 1]:
            for dj in [-1, 0, 1]:
                 grid[i, j].neighbors[di+1][dj+1]=grid[(i+di)%N, (j+dj)%N]

# Animation
fig, ax = plt.subplots()
img = ax.imshow(np.vectorize(lambda x: x.state)(grid), interpolation='nearest')
ani = animation.FuncAnimation(fig, cellclass.update, fargs=(img, grid, N, ), frames = 50,
                              interval=50, save_count=50)

plt.show()
# Out:
# C:\Users\María José Morón\AppData\Local\Temp\ipykernel_12292\3083318762.py:16: UserWarning: You passed in an explicit save_count=50 which is being ignored in favor of frames=50.
#   ani = animation.FuncAnimation(fig, cellclass.update, fargs=(img, grid, N, ), frames = 50,
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
p=Parameters()
city= City(p, Block())
city.plotCity()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
